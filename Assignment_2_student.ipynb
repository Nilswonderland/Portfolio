# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# ...

# %%
kill.isnull().shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill["manner_of_death"].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(x = 'gender', y = 'age', hue = 'manner_of_death', data = kill);

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.swarmplot(x = "gender", y = "age", hue = 'manner_of_death', data = kill, size = 6 ,ax = ax);

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq = 
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq = kill.city.value_counts().head(12)
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq =  kill.city.value_counts().head(12)
city_freq
fig, ax =plt.subplots(figsize=(8,5))
x = city_freq.index
y = city_freq.values
ax = sns.barplot(x, y, data = kill)
ax. set_title("Most dangerous cities", color = 'blue', size = 20)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30);

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(x="city", data=kill, order= city_freq.index)
ax.set_title('Most dangerous cities', color = 'blue', size = 20)
ax.set_xticklabels(ax.get_xticklabels(), rotation= 30);

# %%
city_freq =  kill.city.value_counts().head(12)
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq =  kill.state.value_counts().head(20)
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
state_freq =  kill.state.value_counts().head(20)
state_freq
fig, ax =plt.subplots(figsize=(8,5))
x = state_freq.index
y = state_freq.values
ax = sns.barplot(x, y, data = kill)
ax. set_title("Most dangerous cities", color = 'blue', size = 20)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30);

# %%
plt.figure(figsize=(8,5))
ax = sns.countplot(x="state", data=kill, order= state_freq.index)
ax.set_title('Most dangerous states', color = 'blue', size = 20)
ax.set_xticklabels(ax.get_xticklabels(), rotation= 30);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
plt.figure(figsize=(6,5))
ax = sns.countplot(x=  "signs_of_mental_illness", data=kill, order= illness.index);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq = kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
plt.figure(figsize=(6,5))
ax = sns.countplot(x="threat_level", data=kill, order= threads_freq.index);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
plt.figure(figsize=(6,5))
ax = sns.countplot(x="flee", data=kill, order= flee_freq.index);
